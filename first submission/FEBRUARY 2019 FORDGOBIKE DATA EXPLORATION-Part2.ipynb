# %% [markdown]
# # PARTII (FEBRUARY 2019 FORDGOBIKE DATA EXPLORATION)
# ## by (EKPOT GODSWILL TOM)

# %% [markdown]
# ## Investigation Overview
#
# We perform this analysis to uncover the prevalence of the bike sharing system and factors that may affect it.
#
# ## Dataset Overview
#
# This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df=pd.read_csv('my_data.csv')

# %% [markdown]
# ## A plot to show how the gender is distributen across duration and datehour
# !
# ### This slide establishes the fact that a vast majority of people do not share their bike but it however highlights a few ppoints. From the hue distribution, it can be deduced that women ride for longer periods than men. It can also be noted that the time with the most bike traffic is between 8-9am.

# %%
sns.lmplot(data=df, x="datehour", y="duration_mins", col="bike_share_for_all_trip",height=8,
           hue="member_gender")
plt.title('')
# Out:
# Text(0.5, 1.0, 'A plot to show how the gender is distributen across duration and datehour')

# %% [markdown]
# ## Bike sharing options for users
#
# #### This chart however shows clearly that customers do not use the bike sharing option at all

# %%
sns.lmplot(data=df, x="datehour", y="duration_mins", hue="bike_share_for_all_trip",
           col="user_type")
plt.title('user_type=subscriber')
# Out:
# Text(0.5, 1.0, 'user_type=subscriber')

# %% [markdown]
# ## Bike traffic time chart
#
# #### This chart accurately shows the time of the day with the highest customer usage.  From the chart, we can observe that 7-9am and 4-6pm see the most traffic of riders

# %%
plt.figure(figsize = [10, 7])
sns.countplot(x='datehour',data=df).set_title('Time count for times people use the bike most')
plt.grid(b=None)

# %% [markdown]
# ## User type duration
#
# #### We pbserve here that customers ride for longer periods than subscribers

# %%
plt.figure(figsize = [10,7])
sns.barplot(x='user_type',y='duration_mins',data=df,palette='Blues').set_title('B3:user type ride duration')
# Out:
# Text(0.5, 1.0, 'B3:user type ride duration')

# %% [markdown]
# # Facet grid
#
# ### This is a multivariate chart to demonstrate how member gender relates to user type and how they are affected by member age and duration.
#
# #### The "other" gender has the least values but with higher durations so they could be considered at outliers
# #### There are more male riders than female riders
# #### The duration reducs with age therefore, the older the rider is, the less time he/she is going to ride for
# #### There is little or no difference between theh the distribution of customers and subscribers

# %%
plt.figure(figsize=(15,10))
g = sns.FacetGrid(df, col="member_gender",  row="user_type",height=5)
g.map(sns.scatterplot, "member_age", "duration_mins")
# Out:
# Text(0.5, 1.0, 'facet grid ')

# %%
# !jupyter nbconvert "FEBRUARY 2019 FORDGOBIKE DATA EXPLORATION-Part2.ipynb" --to slides --post serve --no-input --no-prompt
